# %% [markdown]
# <a href="https://colab.research.google.com/github/tarunjit0048/AI-Assignment/blob/main/CGPAand%20Salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x_cgpa = [2,3,4,5]
y_salary = [20000,30000,40000,50000]

# %%
plt.plot(x_cgpa,y_salary,"o--g")
plt.xlabel("CGPA")
plt.ylabel("Salary")
plt.title("SALARY and CGPA Distribution")
plt.show()
